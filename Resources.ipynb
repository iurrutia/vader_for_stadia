# %% [markdown]
# # Twitter resources:
#
# First GOP Debate Twitter Sentiment:
# https://www.kaggle.com/crowdflower/first-gop-debate-twitter-sentiment
#
# Twitter API: https://developer.twitter.com/en/docs/tweets/filter-realtime/api-reference/post-statuses-filter
#
# ### Real time tweets:
#
# Twitter scraper:
# https://github.com/taspinar/twitterscraper/
#
# For past tweets or tweets from the last 7 days:
# Python script for connecting to Twitter stream, gather tweets that match a particular keyword, hashtag or mention and save them on a CSV file: https://github.com/feconroses/gather-tweets-from-stream
#
# About **TWEEPY**: https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/
#
# ### Historical batch tweets (but not free):
# https://developer.twitter.com/en/docs/tweets/batch-historical/overview
#
# ### Free twitter sentiment analysis training data set:
# http://help.sentiment140.com/for-students
#
# ### Free Twitter Datasets Mega Compilation
# https://www.trackmyhashtag.com/blog/twitter-datasets-free/
#
# ## Articles:
#
# https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/
#
# Learning Word Vectors for Sentiment Analysis:
# http://www.iosrjen.org/Papers/Conf.SICTIM-2019/Volume-1/5.%2022-25.pdf

# %% [markdown]
# # Reddit data:
#
# ### Data and analysis example:
#
# https://www.reddit.com/r/dataisbeautiful/comments/a4ac4m/sentiment_analysis_of_various_subreddits_oc/
#     using:
#         https://files.pushshift.io/reddit/ using http://comp.social.gatech.edu/papers/icwsm14.vader.hutto.pdf
#
# The basics of reddit sentiment analysis:
# https://den.dev/blog/reddit-sentiment-analysis/
#
# ### Reddit data on google cloud platform (new version):
# https://console.cloud.google.com/bigquery?p=fh-bigquery&d=reddit_comments&t=2018_10&page=table
#
# ### Sentiment analysis on reddit headlines:
#
# Sentiment Analysis on Reddit News Headlines with Python’s Natural Language Toolkit (NLTK)
# https://www.learndatasci.com/tutorials/sentiment-analysis-reddit-headlines-pythons-nltk/
#
# How to scrape data from Reddit using the Python Reddit API Wrapper(PRAW):
# https://towardsdatascience.com/scraping-reddit-data-1c0af3040768
#
# Basics of computing sentiment for Reddit headlines (without BigQuery):
# https://github.com/dend/data-explorations/blob/master/notebooks/sentiment-analysis-reddit.ipynb
#
#
# ### Clustering 101: https://www.reddit.com/r/datascience/comments/6o0mm3/how_do_you_choose_a_clustering_algorithm/

# %% [markdown]
# ## Other data:
#
# Open data:
#     https://www1.nyc.gov/site/planning/data-maps/open-data.page
#
# NYC GIS:
#     https://gis.ny.gov/gisdata/inventories/results.cfm?SWIS=&sectorIDs=&themeIDs=24
#
# Flights:
#     https://openflights.org/data.html
#
# Global accessibility:
#     https://forobs.jrc.ec.europa.eu/products/gam/sources.php
#
# Directory of geo datasets:
#     http://freegisdata.rtwilson.com/
#
# Wallmart data (in Kaggle competition):
#     https://www.kaggle.com/c/walmart-recruiting-store-sales-forecasting/overview
#
# Data World, libraries:
#     https://data.world/city-of-ny/ne9z-skhf
#
# Pokemon map (for scraping?):
#     https://www.pogomap.info/location/43,663277/-79,466944/14
#
# Openmaps tutorial:
#     https://mdl.library.utoronto.ca/technology/tutorials/exporting-map-data-openstreetmap
#
# OpenMaps:
#     https://www.e-education.psu.edu/geog585/node/739
#
# OpenMaps tutorial:
#     https://automating-gis-processes.github.io/2017/lessons/L7/retrieve-osm-data.html
#
# Fooling around with OMS:
#     https://janakiev.com/blog/openstreetmap-with-python-and-overpass-api/
#
# OpenStreetMap data analysis: how to parse the data with Python?
#     https://oslandia.com/en/2017/07/03/openstreetmap-data-analysis-how-to-parse-the-data-with-python/
#
# Geofabrik:
#     http://download.geofabrik.de/
#
# ## OpenMaps StravaHeatmap overlay:
# Strava heatmap overlay:
#     https://singletrackworld.com/forum/topic/open-streetmaps-with-strava-heat-overlay/
